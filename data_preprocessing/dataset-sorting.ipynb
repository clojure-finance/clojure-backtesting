# %%
import os
import pandas as pd

filename = os.path.join('CRSP-extract.csv')

# %%
df = pd.read_csv(filename, dtype={'CFACPR': 'float64',
       'CFACSHR': 'float64',
       'CUSIP': 'object',
       'HSICCD': 'object',
       'NCUSIP': 'object'})
df.head()
# Out:
#    PERMCO  PERMNO        date              COMNAM    NCUSIP     CUSIP  SICCD  \
# 0       7   14593  1980-12-15  APPLE COMPUTER INC  03783310  03783310   3573
# 1       7   14593  1980-12-16  APPLE COMPUTER INC  03783310  03783310   3573
# 2       7   14593  1980-12-17  APPLE COMPUTER INC  03783310  03783310   3573
# 3       7   14593  1980-12-18  APPLE COMPUTER INC  03783310  03783310   3573
# 4       7   14593  1980-12-19  APPLE COMPUTER INC  03783310  03783310   3573
#
#   HSICCD TICKER  SHRCD  ...      PRC       RET  DLRET VOL  SHROUT  CFACPR  \
# 0   3571   AAPL     11  ...  27.3125 -0.052061    NaN NaN  55.136    56.0
# 1   3571   AAPL     11  ...  25.3125 -0.073227    NaN NaN  55.136    56.0
# 2   3571   AAPL     11  ...  25.9375  0.024691    NaN NaN  55.136    56.0
# 3   3571   AAPL     11  ...  26.6875  0.028916    NaN NaN  55.136    56.0
# 4   3571   AAPL     11  ...  28.3125  0.060890    NaN NaN  55.136    56.0
#
#    CFACSHR    vwretd    ewretd    sprtrn
# ...

# %%
df = df.sort_values(['date', 'TICKER'], ascending=[True, True])
df.head()
# Out:
#        PERMCO  PERMNO        date                            COMNAM NCUSIP  \
# 9092    20750   25785  1962-07-02                 FORD MOTOR CO DEL    NaN
# 22811   20990   12490  1962-07-02  INTERNATIONAL BUSINESS MACHS COR    NaN
# 9093    20750   25785  1962-07-03                 FORD MOTOR CO DEL    NaN
# 22812   20990   12490  1962-07-03  INTERNATIONAL BUSINESS MACHS COR    NaN
# 9094    20750   25785  1962-07-05                 FORD MOTOR CO DEL    NaN
#
#           CUSIP  SICCD HSICCD TICKER  SHRCD  ...      PRC       RET  DLRET  \
# 9092   34537086   3711   3711      F     11  ...   79.500  0.032468    NaN
# 22811  45920010   3573   7379    IBM     11  ...  350.000  0.031688    NaN
# 9093   34537086   3711   3711      F     11  ...   79.500  0.000000    NaN
# 22812  45920010   3573   7379    IBM     11  ...  351.500  0.004286    NaN
# 9094   34537086   3711   3711      F     11  ...   79.625  0.001572    NaN
#
# ...

# %%
df.to_csv('CRSP-extract-sorted.csv', index=False)

# %%
# Compustat

filename = os.path.join('Compustat-extract.csv')

df = pd.read_csv(filename)
df.head()
# Out:
#    gvkey    datadate       conm     ipodate  rdq  datacqtr  datafqtr  \
# 0   1690  1979/12/31  APPLE INC  1980/12/12  NaN   1979.75   1980.00
# 1   1690   1980/3/31  APPLE INC  1980/12/12  NaN   1980.00   1980.25
# 2   1690   1980/6/30  APPLE INC  1980/12/12  NaN   1980.25   1980.50
# 3   1690   1980/9/30  APPLE INC  1980/12/12  NaN   1980.50   1980.75
# 4   1690  1980/12/31  APPLE INC  1980/12/12  NaN   1980.75   1981.00
#
#       cusip     cik TICKER  ...  ivncfq  fincfq  sstkq prstkcq  dltisq  dltrq  \
# 0  37833100  320193   AAPL  ...     NaN     NaN    NaN     NaN     NaN    NaN
# 1  37833100  320193   AAPL  ...     NaN     NaN    NaN     NaN     NaN    NaN
# 2  37833100  320193   AAPL  ...     NaN     NaN    NaN     NaN     NaN    NaN
# 3  37833100  320193   AAPL  ...     NaN     NaN    NaN     NaN     NaN    NaN
# 4  37833100  320193   AAPL  ...     NaN     NaN    NaN     NaN     NaN    NaN
#
#    dpcq  wcapchq  capxq  sppeq
# 0   NaN      NaN    NaN    NaN
# ...

# %%
df = df.sort_values(['datadate', 'TICKER'], ascending=[True, True])
df.head()
# Out:
#      gvkey    datadate                         conm ipodate  rdq  datacqtr  \
# 165   4839  1962/12/31                FORD MOTOR CO     NaN  NaN   1962.75
# 398   6066  1962/12/31  INTL BUSINESS MACHINES CORP     NaN  NaN   1962.75
# 162   4839   1962/3/31                FORD MOTOR CO     NaN  NaN   1962.00
# 395   6066   1962/3/31  INTL BUSINESS MACHINES CORP     NaN  NaN   1962.00
# 163   4839   1962/6/30                FORD MOTOR CO     NaN  NaN   1962.25
#
#      datafqtr      cusip    cik TICKER  ...  ivncfq  fincfq  sstkq prstkcq  \
# 165   1962.75  345370860  37996      F  ...     NaN     NaN    NaN     NaN
# 398   1962.75  459200101  51143    IBM  ...     NaN     NaN    NaN     NaN
# 162   1962.00  345370860  37996      F  ...     NaN     NaN    NaN     NaN
# 395   1962.00  459200101  51143    IBM  ...     NaN     NaN    NaN     NaN
# 163   1962.25  345370860  37996      F  ...     NaN     NaN    NaN     NaN
#
#      dltisq  dltrq  dpcq  wcapchq  capxq  sppeq
# ...

# %%
df.to_csv('Compustat-extract-sorted.csv', index=False)

# %% [markdown]
# ### Real dataset sorting

# %%
# Compustat

filename = os.path.join('data/data-Compustat.csv')

df = pd.read_csv(filename)
df.head()
# Out:
#    gvkey    datadate                   conm ipodate  rdq  datacqtr  datafqtr  \
# 0   1000  1966-03-31  A & E PLASTIK PAK INC     NaN  NaN   1966.00   1966.00
# 1   1000  1966-06-30  A & E PLASTIK PAK INC     NaN  NaN   1966.25   1966.25
# 2   1000  1966-09-30  A & E PLASTIK PAK INC     NaN  NaN   1966.50   1966.50
# 3   1000  1966-12-31  A & E PLASTIK PAK INC     NaN  NaN   1966.75   1966.75
# 4   1000  1967-03-31  A & E PLASTIK PAK INC     NaN  NaN   1967.00   1967.00
#
#        cusip  cik   tic  ...  fincfq sstkq  prstkcq dltisq  dltrq  dvq  dpcq  \
# 0  000032102  NaN  AE.2  ...     NaN   NaN      NaN    NaN    NaN  NaN   NaN
# 1  000032102  NaN  AE.2  ...     NaN   NaN      NaN    NaN    NaN  NaN   NaN
# 2  000032102  NaN  AE.2  ...     NaN   NaN      NaN    NaN    NaN  NaN   NaN
# 3  000032102  NaN  AE.2  ...     NaN   NaN      NaN    NaN    NaN  NaN   NaN
# 4  000032102  NaN  AE.2  ...     NaN   NaN      NaN    NaN    NaN  NaN   NaN
#
#    wcapchq  capxq  sppeq
# ...

# %%
df = df.sort_values(['datadate', 'tic'], ascending=[True, True])
df.head()
# Out:
#         gvkey    datadate                      conm ipodate  rdq  datacqtr  \
# 355937   6990  1961-03-31  MANHATTAN INDUSTRIES INC     NaN  NaN    1961.0
# 315823   6307  1961-03-31       SEARS HOLDINGS CORP     NaN  NaN    1961.0
# 315351   6303  1961-04-30        KDT INDUSTRIES INC     NaN  NaN    1961.0
# 614317  11220  1961-04-30      VORNADO REALTY TRUST     NaN  NaN    1961.0
# 235827   4979  1961-04-30             GAMBLE-SKOGMO     NaN  NaN    1961.0
#
#         datafqtr      cusip        cik    tic  ...  fincfq sstkq  prstkcq  \
# 355937    1961.0  562876102    61946.0  MHT.1  ...     NaN   NaN      NaN
# 315823    1961.0  812350106  1310067.0  SHLDQ  ...     NaN   NaN      NaN
# 315351    1961.0  482455102    55953.0    KDT  ...     NaN   NaN      NaN
# 614317    1961.0  929042109   899689.0    VNO  ...     NaN   NaN      NaN
# 235827    1961.0  364640003        NaN   WIX1  ...     NaN   NaN      NaN
#
#        dltisq  dltrq  dvq  dpcq  wcapchq  capxq  sppeq
# ...

# %%
df.to_csv('data-Compustat-sorted.csv', index=False)

# %%
# CRSP

filename = os.path.join('data/data-CRSP.csv')

df = pd.read_csv(filename)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    PERMCO  PERMNO        date                        COMNAM       NCUSIP  \
# 0       2   14403  1972-12-15  ANGLO AMERICAN GOLD INVT LTD  3.48703e+06
# 1       2   14403  1972-12-18  ANGLO AMERICAN GOLD INVT LTD  3.48703e+06
# 2       2   14403  1972-12-19  ANGLO AMERICAN GOLD INVT LTD  3.48703e+06
# 3       2   14403  1972-12-20  ANGLO AMERICAN GOLD INVT LTD  3.48703e+06
# 4       2   14403  1972-12-21  ANGLO AMERICAN GOLD INVT LTD  3.48703e+06
#
#      CUSIP SICCD HSICCD TICKER  SHRCD  ...  VOL  SHROUT  DIVAMT FACPR FACSHR  \
# 0  3487050  000Z   1040  AAGIY     30  ...  NaN  21.952     NaN   NaN    NaN
# 1  3487050  000Z   1040  AAGIY     30  ...  NaN  21.952     NaN   NaN    NaN
# ...

# %%
df = df.sort_values(['date', 'TICKER'], ascending=[True, True])
df.head()
# Out:
#           PERMCO  PERMNO        date                   COMNAM NCUSIP  \
# 317355        90   10284  1926-01-02      AMERICAN EXPRESS CO    NaN
# 2954532      921   11287  1926-01-02   AMERICAN LOCOMOTIVE CO    NaN
# 4043095     1265   11631  1926-01-02  DE BEERS CONS MINES LTD    NaN
# 12969699    4083   14349  1926-01-02          REPLOGLE STL CO    NaN
# 13317651    4178   14461  1926-01-02                CHILDS CO    NaN
#
#              CUSIP SICCD HSICCD TICKER  SHRCD  ...    VOL SHROUT  DIVAMT  \
# 317355     2581690  7390   7390    NaN     10  ...    0.0  0.180     NaN
# 2954532   17286410  3740   3743    NaN     10  ...  500.0  0.500     NaN
# 4043095   24025330  1400   1499    NaN     30  ...    0.0  0.080     NaN
# 12969699  85234110  3310   2390    NaN     10  ...  300.0  0.500     NaN
# 13317651  83543840  5810   7011    NaN     11  ...  200.0  0.334     NaN
#
#          FACPR FACSHR    CFACPR  CFACSHR    vwretd    ewretd  sprtrn
# ...

# %%
df.to_csv('data-CRSP-sorted.csv', index=False)

# %%
# check


filename = os.path.join('data-CRSP-sorted.csv')

df = pd.read_csv(filename)
df.head()
